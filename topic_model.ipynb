# %% [markdown]
# # Topic Modeling with *Frankenstein*
#
# This notebook runs through some of the basics of topic modeling using the novel **Frankenstein** by Mary Shelly.
#
# Followed tutorial from https://towardsdatascience.com/topic-modelling-in-python-with-nltk-and-gensim-4ef03213cd21

# %% [markdown]
# ## Text Cleaning
#
# Tokenize each word, replace urls with the token URL, email address with SCREEN_NAME, and all other tokens are lower case

# %%
import spacy
spacy.load('en')
from spacy.lang.en import English
parser = English()


def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens

# %% [markdown]
# Use word net to get roots of words, ie running and ran -> run

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('wordnet')


from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma
    
from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# [nltk_data] Downloading package wordnet to /Users/zeke/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Get a set of stop words from nltk

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
en_stop.add('could')
en_stop.add('would')
en_stop.add('might')
# Out:
# [nltk_data] Downloading package stopwords to /Users/zeke/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Function that converts raw text to a list of tokens for lda

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
import random
text_data = []
with open('Frankenstein.txt') as f:
    for line in f:
        tokens = prepare_text_for_lda(line)
        if random.random() > .5:
            print(tokens)
            text_data.append(tokens)
# Out:
# ['letter']
# []
# ['petersburgh']
# []
# ['commencement', 'enterprise', 'regard']
# ['foreboding', 'arrive', 'yesterday', 'first', 'assure']
# ['petersburgh', 'northern', 'breeze', 'cheek']
# ['braces', 'nerves', 'fill', 'delight', 'understand']
# ['advance', 'give', 'foretaste', 'clime']
# ['frost', 'desolation', 'present', 'imagination']
# ['region', 'beauty', 'delight', 'margaret']
# ['trust', 'precede', 'navigator', 'frost', 'banish']
# ['sailing', 'waft', 'surpass']
# ['wonder', 'beauty', 'every', 'region', 'hitherto', 'discover', 'habitable']
# ['regulate', 'thousand', 'celestial', 'observation', 'require']
# ['shall', 'satiate', 'ardent', 'curiosity', 'sight', 'world']
# ['never', 'visit', 'tread', 'never', 'imprint']
# ['enticement', 'sufficient']
# ['native', 'river', 'suppose', 'conjecture', 'false']
# ['contest', 'inestimable', 'benefit', 'shall', 'confer']
# ['possible', 'effect', 'undertaking']
# ['reflection', 'dispel', 'agitation', 'begin']
# ['letter', 'heart', 'enthusiasm', 'elevate']
# ['heaven', 'nothing', 'contribute', 'tranquillise']
# ['steady', 'purpose', 'point', 'intellectual']
# ['prospect', 'arrive', 'north', 'pacific', 'ocean']
# ['passionately', 'reading', 'volume', 'study']
# ['night', 'familiarity', 'increase', 'regret']
# ['become', 'live', 'paradise', 'creation']
# ['imagine', 'obtain', 'niche', 'temple']
# ['names', 'homer', 'shakespeare', 'consecrate']
# ['acquaint', 'failure', 'heavily', 'disappointment']
# ['thought', 'turn', 'channel', 'earlier']
# []
# ['years', 'pass', 'since', 'resolve', 'present', 'undertaking']
# ['remember', 'dedicate']
# ['accompany', 'whale', 'fisher', 'several', 'expedition', 'north']
# ['voluntarily', 'endure', 'famine', 'thirst', 'sleep', 'often']
# ['branch', 'physical', 'science', 'naval', 'adventurer', 'derive']
# ['greatest', 'practical', 'advantage', 'twice', 'actually', 'hire']
# ['greenland', 'whaler', 'acquit', 'admiration']
# ['little', 'proud', 'captain', 'offer', 'second']
# ['dignity', 'vessel', 'entreat', 'remain', 'greatest']
# ['every', 'enticement', 'wealth', 'place', 'encourage']
# ['hope', 'fluctuate', 'spirits', 'often', 'depress']
# ['proceed', 'difficult', 'voyage', 'emergency']
# ['others', 'sometimes', 'sustain', 'failing']
# ['opinion', 'agreeable', 'english', 'stagecoach']
# ['excessive', 'wrap', 'dress']
# ['already', 'adopt', 'great', 'difference', 'walking']
# ['remain', 'seat', 'motionless', 'hours', 'exercise']
# ['ambition', 'petersburgh']
# ['archangel']
# []
# ['among', 'accustom', 'whale', 'fishing', 'intend']
# ['month', 'shall', 'return', 'sister']
# ['answer', 'question', 'succeed', 'month', 'perhaps', 'years']
# []
# []
# ['farewell', 'excellent', 'margaret', 'heaven', 'shower', 'blessing']
# ['testify', 'gratitude']
# ['kindness']
# []
# ['affectionate', 'brother']
# []
# []
# []
# []
# ['saville', 'england']
# []
# []
# ['slowly', 'pass', 'encompass', 'frost']
# ['second', 'take', 'towards', 'enterprise', 'hire']
# ['vessel', 'occupy', 'collecting', 'sailor']
# ['already', 'engage', 'appear', 'depend', 'certainly']
# ['never', 'satisfy']
# ['absence', 'object', 'severe']
# ['friend', 'margaret', 'glowing', 'enthusiasm', 'success']
# ['participate', 'assail', 'disappointment']
# ['courageous', 'possess', 'cultivate', 'capacious', 'whose']
# ['friend', 'repair', 'fault', 'brother', 'ardent', 'execution']
# ['educate', 'first', 'fourteen', 'years']
# ['common', 'nothing', 'uncle', 'thomas', 'book', 'voyage']
# ['become', 'acquaint', 'celebrate', 'poet']
# ['keeping', 'greatly', 'friend', 'sense']
# ['enough', 'despise', 'romantic', 'affection', 'enough']
# []
# ['useless', 'complaint', 'shall', 'certainly', 'friend']
# ['ocean', 'archangel', 'among', 'merchant', 'seaman']
# ['feelings', 'unallied', 'dross', 'human', 'nature']
# ['rugged', 'bosom', 'lieutenant', 'instance', 'wonderful', 'courage']
# ['enterprise', 'madly', 'desirous', 'glory', 'rather', 'phrase']
# ['unsoftened', 'cultivation', 'retain', 'noble', 'endowment']
# ['finding', 'unemployed', 'easily', 'engage', 'assist']
# ['enterprise']
# []
# ['gentleness', 'mildness', 'discipline']
# ['circumstance', 'add', 'know', 'integrity', 'dauntless', 'courage']
# ['spend', 'gentle', 'feminine', 'fosterage', 'refine']
# ['necessary', 'hear', 'mariner', 'equally', 'note', 'kindliness']
# ['peculiarly', 'fortunate', 'secure', 'services', 'hear']
# ['first', 'rather', 'romantic', 'manner']
# ['happiness', 'briefly', 'story', 'years', 'love']
# ['young', 'russian', 'moderate', 'fortune', 'amass', 'considerable']
# ['mistress', 'destine', 'ceremony', 'bathe']
# ['tears', 'throw', 'entreat', 'spare']
# ['prize', 'money', 'purchase', 'stock', 'solicit', 'young']
# ['woman', 'father', 'consent', 'marriage', 'lover']
# ['hear', 'former', 'mistress', 'married', 'accord']
# ['ignorant', 'carelessness', 'attend', 'render', 'conduct']
# ['astonish', 'detract', 'interest', 'sympathy']
# ['conceive', 'consolation', 'toil', 'never']
# ['sufficiently', 'confide', 'prudence', 'considerateness', 'whenever']
# ['undertaking', 'impossible', 'communicate', 'conception']
# ['trembling', 'sensation', 'pleasurable', 'fearful']
# ['alarm', 'safety']
# ['woeful', 'ancient', 'mariner', 'smile', 'allusion']
# ['disclose', 'secret', 'often', 'attribute', 'attachment']
# ['passionate', 'enthusiasm', 'dangerous', 'mystery', 'ocean']
# ['production', 'imaginative', 'modern', 'poet', 'something']
# ['industrious', 'painstaking', 'workman', 'execute', 'perseverance']
# ['traverse', 'immense', 'return', 'southern']
# ['africa', 'america', 'expect', 'success']
# ['support', 'spirits', 'tenderly']
# []
# ['robert', 'walton']
# []
# []
# []
# []
# ['write', 'line', 'haste', 'advance']
# ['voyage', 'letter', 'reach', 'england', 'merchantman']
# ['native', 'perhaps', 'years', 'however']
# ['floating', 'sheet', 'continually', 'indicate', 'danger']
# ['region', 'towards', 'advance', 'appear', 'dismay']
# ['speedily', 'towards', 'shore', 'ardently', 'desire']
# ['attain', 'breathe', 'degree', 'renovate', 'warmth']
# ['expect']
# []
# ['accident', 'experience', 'navigator', 'scarcely', 'remember', 'record']
# ['shall', 'content', 'nothing', 'worse', 'happen', 'voyage']
# []
# ['adieu', 'margaret', 'assure']
# ['rashly', 'encounter', 'danger']
# ['persevere', 'prudent']
# ['success', 'shall', 'crown', 'endeavour', 'wherefore']
# ['witness', 'testimony', 'triumph']
# ['still', 'proceed', 'untamed', 'obedient', 'element']
# ['finish', 'heaven', 'bless', 'beloved', 'sister']
# []
# []
# []
# ['letter']
# []
# []
# ['august']
# []
# ['recording', 'although', 'probable']
# ['monday', 'nearly', 'surround', 'close']
# ['float', 'situation', 'somewhat', 'dangerous', 'especially']
# ['compass', 'round', 'thick', 'accordingly']
# ['every', 'direction', 'irregular', 'plain', 'seem']
# ['shape', 'apparently', 'gigantic', 'stature']
# ['sledge', 'guide', 'watch', 'rapid', 'progress']
# []
# ['hundred', 'mile', 'apparition', 'seem', 'denote']
# ['impossible', 'follow', 'track', 'observe']
# ['greatest', 'attention']
# []
# ['night', 'break', 'free', 'however']
# ['float', 'breaking', 'profit']
# []
# ['morning', 'however', 'light']
# ['found', 'sailor', 'vessel', 'apparently']
# ['talking', 'someone', 'sledge']
# ['fragment', 'remain', 'alive', 'human']
# ['traveller', 'seem', 'savage', 'inhabitant']
# ['master', 'captain', 'allow', 'perish']
# []
# ['perceive', 'stranger', 'address', 'english', 'although']
# ['foreign', 'accent', 'board', 'vessel']
# ['conceive', 'astonishment', 'hearing', 'question', 'address']
# ['suppose', 'vessel', 'resource']
# ['reply', 'however', 'voyage', 'discovery', 'towards']
# ['northern']
# []
# ['hearing', 'appear', 'satisfy', 'consent', 'board']
# ['margaret', 'capitulate']
# ['safety', 'surprise', 'boundless', 'limb']
# ['suffering', 'never', 'wretched', 'condition', 'attempt']
# ['faint', 'accordingly', 'bring']
# ['restore', 'animation', 'rubbing', 'brandy', 'force']
# ['swallow', 'small', 'quantity', 'show', 'sign']
# ['wrap', 'blanket', 'place', 'chimney']
# ['kitchen', 'stove', 'degree', 'recover', 'little']
# ['restore', 'wonderfully']
# []
# ['pass', 'manner', 'speak', 'often']
# ['fear', 'suffering', 'deprive', 'understanding']
# ['measure', 'recover', 'remove', 'cabin']
# ['attend', 'permit', 'never']
# ['perform', 'kindness', 'towards']
# ['benevolence', 'sweetness', 'never', 'equal']
# ['generally', 'melancholy', 'despair', 'sometimes', 'gnash']
# ['allow', 'torment', 'curiosity', 'state']
# ['whose', 'restoration', 'evidently', 'depend', 'entire', 'repose']
# ['strange', 'vehicle']
# []
# ['reply']
# []
# ['pursued', 'travel', 'fashion']
# []
# []
# ['pursued', 'alone']
# []
# []
# ['destroy', 'sledge', 'reply', 'answer']
# ['midnight', 'traveller', 'arrive', 'place', 'safety']
# ['spirit', 'animate', 'decay', 'frame']
# ['stranger', 'manifest', 'greatest', 'eagerness', 'watch']
# ['sledge', 'appear', 'persuade', 'remain']
# ['notice', 'object', 'appear', 'sight']
# []
# ['journal', 'relate', 'strange', 'occurrence']
# ['constant', 'grief', 'fill', 'sympathy', 'compassion']
# ['attractive', 'amiable']
# ['letters', 'margaret', 'friend']
# ['ocean', 'found', 'spirit']
# ['heart']
# []
# ['fresh', 'incident', 'record']
# []
# []
# ['august']
# []
# ['admiration', 'astonish', 'degree']
# ['speak', 'although', 'words', 'cull', 'choice']
# ['unhappy', 'utterly', 'occupy', 'misery']
# ['interest', 'deeply', 'project', 'others', 'frequently']
# ['converse', 'communicate', 'without']
# ['disguise', 'enter', 'attentively', 'argument', 'favour']
# ['eventual', 'success', 'every', 'minute', 'detail', 'measure', 'take']
# ['sacrifice', 'fortune', 'existence', 'every', 'furtherance']
# ['acquirement', 'knowledge', 'seek', 'dominion']
# ['gloom', 'spread', 'listener', 'countenance', 'first']
# ['perceive', 'try', 'suppress', 'emotion', 'place', 'hands']
# ['voice', 'quiver', 'fail', 'behold', 'tears', 'trickle']
# ['reveal']
# []
# ['words', 'imagine', 'strongly', 'excite', 'curiosity']
# ['paroxysm', 'grief', 'seize', 'stranger', 'overcome', 'weaken']
# ['power', 'hours', 'repose', 'tranquil', 'conversation']
# ['conquer', 'violence', 'feelings', 'appear', 'despise']
# ['slave', 'passion', 'quelling', 'tyranny']
# ['despair', 'converse', 'concern', 'personally', 'ask']
# ['unfashioned', 'creature', 'wise', 'better', 'dear']
# ['friend', 'ought']
# ['perfectionate', 'faulty', 'nature', 'friend']
# ['noble', 'human', 'creature', 'entitle', 'therefore', 'judge', 'respect']
# []
# []
# ['countenance', 'become', 'expressive', 'settle']
# ['grief', 'touch', 'heart', 'silent', 'presently']
# []
# ['elevate', 'earth', 'double', 'existence']
# ['suffer', 'misery', 'overwhelm', 'disappointment']
# ['retire', 'celestial', 'spirit']
# ['wanderer', 'tutor']
# ['somewhat', 'fastidious', 'render']
# ['endeavour', 'discover', 'quality', 'posse']
# ['elevate', 'immeasurably', 'person']
# []
# []
# []
# []
# ['yesterday', 'stranger', 'easily', 'perceive', 'captain']
# ['gratification', 'wish', 'serpent', 'sting']
# ['relation', 'disaster']
# ['direct', 'succeed', 'undertaking', 'console']
# ['failure', 'prepare', 'occurrence', 'usually']
# ['deem', 'marvellous', 'among', 'tamer', 'scene', 'nature']
# ['encounter', 'unbelief', 'perhaps', 'ridicule', 'things']
# ['appear', 'possible', 'mysterious', 'region']
# ['provoke', 'laughter', 'unacquainted', 'vary', 'power']
# ['internal', 'evidence', 'truth', 'event', 'compose']
# []
# ['useless', 'nearly', 'fulfil', 'event']
# ['perceive', 'wish', 'interrupt', 'mistake']
# ['friend', 'allow', 'nothing', 'alter']
# ['destiny', 'listen', 'history', 'perceive', 'irrevocably']
# ['determine']
# ['commence', 'narrative']
# ['leisure', 'promise', 'warm', 'thanks']
# ['resolve', 'every', 'night', 'imperatively', 'occupy', 'duty']
# ['engage', 'least', 'note']
# ['manuscript', 'doubtless', 'afford', 'greatest', 'pleasure']
# ['melancholy', 'sweetness', 'raise']
# []
# []
# []
# ['counsellor', 'syndic', 'father', 'fill', 'several', 'public']
# ['affairs', 'country', 'variety', 'circumstances', 'prevent']
# ['marry', 'early', 'decline', 'become']
# ['refrain', 'relate', 'intimate', 'friend']
# ['merchant', 'flourish', 'state', 'numerous']
# ['proud', 'unbend', 'disposition', 'poverty']
# ['oblivion', 'country', 'formerly']
# ['therefore', 'honourable', 'manner', 'retreated']
# ['daughter', 'lucerne', 'live', 'unknown']
# ['deeply', 'grieve', 'retreat', 'unfortunate', 'circumstances']
# ['bitterly', 'deplore', 'false', 'pride', 'friend', 'conduct']
# ['little', 'worthy', 'affection', 'unite']
# ['endeavour', 'persuade', 'begin']
# ['save', 'small', 'money', 'wreck', 'fortune']
# ['meantime', 'hope', 'procure', 'respectable', 'employment']
# ['merchant', 'house', 'interval', 'consequently', 'spend', 'inaction']
# ['reflection', 'length']
# []
# ['various', 'means', 'contrive', 'pittance', 'scarcely', 'sufficient']
# ['support']
# []
# ['several', 'month', 'pass', 'manner', 'father', 'worse']
# ['orphan', 'beggar', 'overcome', 'kneel']
# ['beaufort', 'coffin', 'weeping', 'bitterly', 'father', 'enter']
# ['relation', 'years', 'event', 'caroline', 'become']
# ['circumstance', 'seem', 'unite', 'closer', 'bond', 'devote']
# ['render', 'necessary', 'approve', 'highly']
# ['strongly', 'perhaps', 'former', 'years', 'suffer']
# ['worship', 'attachment', 'mother', 'differ', 'wholly']
# ['sorrow', 'endure', 'inexpressible', 'grace']
# ['convenience', 'strive', 'shelter', 'exotic']
# ['shelter', 'gardener', 'every', 'rough', 'surround']
# ['excite', 'pleasurable', 'emotion']
# ['constant', 'spirit', 'shake']
# ['years', 'elapse', 'previous', 'marriage', 'father']
# ['restorative', 'weaken', 'frame']
# []
# ['several', 'years', 'child', 'attach']
# ['seem', 'inexhaustible', 'store', 'affection']
# ['father', 'smile', 'benevolent', 'pleasure', 'regard']
# ['first', 'recollection', 'plaything', 'something']
# ['heaven', 'bring', 'whose', 'future']
# ['towards', 'given', 'add', 'active', 'spirit']
# ['tenderness', 'animate', 'imagine']
# ['control', 'guide', 'silken', 'seem']
# []
# ['mother', 'desire']
# ['daughter', 'continue', 'single', 'offspring']
# ['pass', 'shore', 'benevolent']
# ['mother', 'necessity']
# ['attract', 'notice', 'singularly', 'disconsolate', 'number']
# ['working', 'labour', 'distribute', 'scanty']
# ['appear', 'different', 'stock', 'others']
# ['hardy', 'little', 'vagrant', 'child']
# ['bright', 'living', 'despite', 'poverty']
# ['clear', 'ample', 'cloudless', 'moulding']
# ['expressive', 'sensibility', 'sweetness', 'behold']
# ['bearing', 'celestial', 'stamp', 'feature']
# []
# ['people', 'nurse', 'better']
# ['married', 'eldest', 'child', 'father']
# ['charge', 'italian', 'nurse', 'memory', 'antique', 'glory']
# ['italy', 'among', 'schiavi', 'ognor', 'frementi', 'exert']
# ['weakness', 'whether', 'still', 'linger', 'dungeon', 'austria']
# ['beggar', 'continue', 'foster', 'parent', 'bloom']
# []
# ['villa', 'child', 'fair', 'picture', 'cherub', 'creature', 'seem']
# ['radiance', 'look', 'whose', 'motion', 'lighter']
# ['chamois', 'hill', 'apparition', 'explain']
# ['consult', 'village', 'priest', 'result', 'elizabeth', 'lavenza']
# ['become', 'inmate', 'parent', 'house']
# ['pleasure']
# ['everyone', 'love', 'elizabeth', 'passionate', 'almost', 'reverential']
# ['mother', 'playfully', 'pretty', 'present']
# ['present', 'elizabeth', 'promise', 'childish']
# ['seriousness', 'interpret', 'words', 'literally', 'look', 'elizabeth']
# ['protect', 'cherish', 'praise', 'bestow']
# ['receive', 'possession', 'call']
# ['familiarly', 'cousin', 'expression']
# ['sister', 'since', 'death']
# []
# []
# []
# []
# []
# ['bring', 'together', 'quite', 'difference']
# ['diversity', 'contrast', 'subsist', 'character']
# ['near', 'together', 'elizabeth', 'calm', 'concentrate']
# ['majestic', 'wondrous', 'scene', 'surround', 'swiss']
# ['companion', 'contemplate', 'serious', 'satisfy', 'spirit']
# ['earliest', 'sensation', 'remember']
# []
# ['birth', 'second', 'junior', 'seven', 'years', 'parent']
# ['eastern', 'shore', 'distance', 'rather']
# ['league', 'reside', 'principally', 'latter']
# ['temper', 'avoid', 'crowd', 'attach', 'fervently']
# ['clerval', 'merchant', 'geneva', 'singular']
# ['talent', 'fancy', 'love', 'enterprise', 'hardship', 'danger']
# ['deeply', 'book', 'chivalry', 'romance']
# ['compose', 'heroic', 'song', 'begin', 'write', 'enchantment']
# ['knightly', 'adventure', 'try', 'play', 'enter']
# ['masquerade', 'character', 'draw', 'hero']
# ['roncesvalles', 'round', 'table', 'arthur', 'chivalrous']
# ['train', 'blood', 'redeem', 'sepulchre', 'hands']
# ['human', 'pass', 'happy', 'childhood']
# ['parent', 'possess', 'spirit', 'kindness', 'indulgence']
# ['tyrant', 'accord']
# ['discern', 'peculiarly', 'fortunate', 'gratitude', 'assist']
# []
# ['temper', 'sometimes', 'violent', 'passion', 'vehement']
# ['eager', 'desire', 'learn', 'learn', 'things']
# ['indiscriminately', 'confess', 'neither', 'structure', 'language']
# ['government', 'politics', 'various', 'state']
# ['possess', 'attraction', 'secret', 'heaven', 'earth']
# ['desire', 'learn', 'whether', 'outward', 'substance']
# ['things', 'inner', 'spirit', 'nature', 'mysterious']
# ['meanwhile', 'clerval', 'occupy', 'speak', 'moral']
# ['elizabeth', 'shine', 'shrine', 'dedicate', 'peaceful']
# ['sympathy', 'smile', 'voice', 'sweet', 'glance']
# ['celestial', 'bless', 'animate']
# ['subdue', 'semblance', 'gentleness']
# ['clerval', 'aught', 'entrench', 'noble', 'spirit', 'clerval']
# ['perfectly', 'humane', 'thoughtful']
# ['generosity', 'kindness', 'tenderness', 'amidst', 'passion']
# ['adventurous', 'exploit', 'unfold', 'loveliness']
# ['beneficence', 'soaring']
# []
# ['misfortune', 'taint', 'change', 'bright', 'vision']
# ['extensive', 'usefulness', 'gloomy', 'narrow', 'reflection', 'besides']
# ['drawing', 'picture', 'early', 'record', 'event']
# ['insensible', 'steps', 'misery']
# ['account', 'birth', 'passion', 'afterwards', 'rule']
# ['destiny', 'arise', 'mountain', 'river', 'ignoble', 'almost']
# ['forget', 'source', 'swelling', 'proceed', 'become', 'torrent']
# []
# ['therefore', 'narration', 'state', 'fact']
# ['predilection', 'science', 'thirteen', 'years']
# ['party', 'pleasure', 'bath', 'thonon', 'inclemency']
# ['chance', 'volume', 'works', 'cornelius', 'agrippa', 'open']
# ['light', 'seem', 'bound', 'communicate']
# []
# ['instead', 'remark', 'father', 'take', 'pains', 'explain']
# ['principle', 'agrippa', 'entirely', 'explode', 'modern']
# ['former', 'practical', 'circumstances']
# ['certainly', 'throw', 'agrippa', 'aside', 'content']
# ['imagination', 'warm', 'return', 'greater', 'ardour']
# ['receive', 'fatal', 'impulse', 'cursory', 'glance']
# ['acquaint', 'contents', 'continue', 'greatest']
# []
# ['return', 'first', 'procure', 'whole', 'works']
# ['study', 'fancy', 'writer', 'delight', 'appear']
# ['imbue', 'fervent', 'longing', 'penetrate', 'secret']
# ['philosopher', 'always', 'study', 'discontent', 'unsatisfied']
# ['shell', 'beside', 'great', 'unexplored', 'ocean', 'truth']
# ['successor', 'branch', 'natural', 'philosophy', 'acquaint']
# ['appear', 'apprehension', 'tiro', 'engage']
# ['pursuit']
# ['practical', 'learn', 'philosopher', 'little']
# ['partially', 'unveil', 'nature', 'immortal']
# ['anatomise', 'names', 'speak', 'final', 'cause', 'cause']
# ['secondary', 'tertiary', 'grade', 'utterly', 'unknown']
# ['book', 'penetrate', 'deep']
# ['aver', 'become']
# ['disciple', 'appear', 'strange', 'arise', 'eighteenth']
# ['geneva', 'great', 'degree', 'teach', 'regard', 'favourite']
# ['child', 'blindness', 'add', 'student', 'thirst', 'knowledge']
# ['diligence', 'search', 'philosopher', 'stone', 'elixir']
# ['banish', 'disease', 'human', 'frame', 'render', 'invulnerable']
# ['violent', 'death']
# ['eagerly', 'seek', 'incantation', 'always', 'unsuccessful']
# ['skill', 'fidelity', 'instructor']
# ['multifarious', 'knowledge', 'guide', 'ardent', 'imagination', 'childish']
# []
# ['fifteen', 'years', 'retire', 'house']
# ['frightful', 'loudness', 'various', 'quarters', 'heavens', 'remain']
# ['beautiful', 'stand', 'twenty', 'yard', 'house']
# ['dazzle', 'light', 'vanish', 'disappear', 'nothing']
# ['shock', 'entirely', 'reduce', 'ribbon', 'never', 'behold']
# ['anything', 'utterly', 'destroy']
# ['unacquainted', 'obvious']
# ['philosophy', 'excite', 'catastrophe', 'enter']
# ['know', 'engage', 'attention', 'suddenly']
# ['despicable', 'caprice', 'perhaps']
# ['occupation', 'natural', 'history', 'progeny', 'deform']
# ['abortive', 'creation', 'entertain', 'greatest', 'disdain']
# ['strangely', 'soul', 'construct', 'slight', 'ligament']
# ['almost', 'miraculous', 'change', 'inclination']
# ['follow', 'relinquishing', 'ancient', 'latterly', 'torment']
# ['study', 'teach', 'associate']
# []
# ['strong', 'effort', 'spirit', 'ineffectual']
# ['destiny', 'potent', 'immutable', 'decree', 'utter']
# ['terrible', 'destruction']
# []
# []
# ['chapter']
# []
# ['attain', 'seventeen', 'parent', 'resolve']
# ['become', 'student', 'university', 'ingolstadt']
# ['necessary', 'completion', 'education']
# ['acquaint', 'customs', 'native', 'country']
# ['departure', 'therefore', 'fix', 'early']
# ['greatest', 'danger', 'illness', 'argument', 'urge']
# ['persuade', 'mother', 'refrain', 'attending', 'first']
# ['yield', 'entreaty', 'hear']
# ['attend', 'sickbed', 'watchful', 'attention', 'triumph', 'malignity']
# ['sicken', 'fever', 'accompany', 'alarm', 'symptom']
# ['look', 'medical', 'attendant', 'prognosticate', 'worst', 'event']
# ['deathbed', 'fortitude', 'benignity', 'woman', 'desert']
# ['join', 'hands', 'elizabeth']
# ['beloved']
# ['thought', 'befit', 'endeavour', 'resign', 'cheerfully']
# ['death', 'indulge', 'meeting', 'another', 'world']
# []
# ['calmly', 'countenance', 'express', 'affection', 'death']
# ['describe', 'feelings', 'whose', 'dearest']
# ['persuade', 'every']
# ['whose', 'existence', 'appear', 'departed']
# ['extinguish', 'sound', 'voice', 'familiar']
# ['hush', 'never', 'hear', 'reflection']
# ['describe', 'sorrow']
# ['duty', 'ought', 'perform', 'continue', 'course']
# ['death', 'house', 'mourning', 'thick']
# ['unwilling', 'sight', 'remain']
# ['indeed', 'veil', 'grief', 'strive', 'comforter']
# ['look', 'steadily', 'assume', 'duty', 'courage']
# ['recall', 'sunshine', 'smile', 'spend']
# ['forget', 'regret', 'endeavour', 'forget']
# []
# ['departure', 'length', 'arrive', 'clerval', 'spend']
# ['evening', 'endeavour', 'persuade', 'father', 'permit']
# ['aspiration', 'ambition', 'henry', 'deeply', 'misfortune']
# ['debar', 'liberal', 'education', 'little']
# ['restrain', 'resolve', 'chain', 'miserable', 'details']
# []
# ['persuade', 'farewell']
# ['retire', 'pretence', 'seeking', 'repose', 'fancy']
# ['deceive', 'morning', 'descend']
# ['carriage', 'convey', 'father']
# ['bless', 'clerval', 'press', 'elizabeth']
# []
# ['throw', 'chaise', 'convey', 'indulge']
# ['melancholy', 'reflection', 'surround']
# ['amiable', 'companion', 'continually', 'engage', 'endeavour', 'bestow', 'mutual']
# ['remarkably', 'seclude', 'domestic', 'given', 'invincible']
# ['repugnance', 'countenance', 'love', 'brother', 'elizabeth']
# ['totally', 'unfit', 'company', 'stranger', 'reflection']
# ['ardently', 'desire', 'acquisition', 'knowledge', 'often']
# ['thought', 'remain', 'youth', 'cooped', 'place']
# []
# ['sufficient', 'leisure', 'reflection']
# ['morning', 'deliver', 'letters', 'introduction', 'visit']
# ['principal', 'professor', 'chance', 'rather']
# ['influence', 'angel', 'destruction', 'assert', 'omnipotent']
# ['moment', 'turn', 'reluctant', 'steps', 'father']
# ['uncouth', 'deeply', 'imbue', 'secret', 'science']
# ['ask', 'several', 'question', 'concern', 'progress', 'different', 'branch']
# ['reply', 'affirmative', 'every', 'minute', 'continue', 'krempe']
# ['useless', 'names', 'desert', 'live']
# ['enough', 'inform', 'fancy']
# ['greedily', 'imbibe', 'thousand', 'years', 'musty']
# []
# ['treat', 'natural', 'philosophy', 'desire', 'procure']
# ['philosophy', 'general', 'relations', 'waldman', 'fellow']
# ['professor', 'lecture', 'chemistry', 'alternate']
# []
# ['return', 'disappoint']
# ['consider', 'author', 'useless', 'professor', 'reprobate']
# ['return', 'incline', 'recur', 'study']
# ['strain', 'perhaps', 'given', 'account', 'conclusion']
# ['content', 'result', 'promise', 'modern', 'professor', 'natural']
# ['science', 'confusion', 'idea', 'account']
# ['extreme', 'youth', 'guide', 'matter', 'retrod']
# ['besides', 'contempt', 'modern', 'natural', 'philosophy']
# ['immortality', 'power', 'view', 'although', 'futile', 'grand']
# ['scene', 'change', 'ambition', 'inquirer', 'seem', 'limit']
# ['science', 'chiefly', 'found', 'require', 'exchange', 'chimera']
# ['reflection', 'first', 'three']
# ['residence', 'ingolstadt', 'chiefly', 'spend', 'become']
# ['acquaint', 'locality', 'principal', 'resident']
# ['abode', 'ensue', 'commence', 'thought', 'information']
# ['sentence', 'pulpit', 'recollect']
# ['temple', 'nearly', 'black', 'person']
# ['short', 'remarkably', 'erect', 'voice', 'sweet', 'hear']
# ['begin', 'lecture', 'recapitulation', 'history', 'chemistry']
# ['fervour', 'names', 'distinguish', 'discoverer']
# ['cursory', 'present', 'state', 'science', 'explain']
# ['shall', 'never', 'forget']
# ['promise', 'impossibility', 'perform', 'nothing', 'modern', 'masters']
# ['breathe', 'acquire', 'almost', 'unlimited', 'power']
# ['invisible', 'world', 'shadow']
# ['enounce', 'destroy']
# ['grappling', 'palpable', 'enemy', 'various']
# ['touch', 'form', 'mechanism', 'chord', 'chord']
# ['already', 'mark', 'pioneer', 'explore', 'unknown', 'power']
# []
# ['close', 'night', 'internal', 'state']
# ['remain', 'resolution', 'return', 'ancient', 'study']
# ['natural', 'talent', 'waldman', 'visit']
# ['manners', 'private', 'attractive', 'public']
# ['house', 'replace', 'greatest', 'affability', 'kindness']
# ['narration', 'concern', 'study', 'smile', 'names', 'cornelius']
# ['exhibit', 'whose', 'indefatigable']
# ['knowledge', 'easy', 'names']
# ['great', 'degree', 'instrument', 'bringing', 'light']
# ['labour', 'genius', 'however', 'erroneously', 'direct', 'scarcely']
# ['ultimately', 'turning', 'solid', 'advantage', 'mankind']
# ['labour', 'request', 'advice', 'concern', 'book', 'ought']
# ['procure']
# ['happy', 'waldman', 'gain']
# ['greatest', 'improvement', 'account']
# ['neglect', 'branch', 'science', 'sorry']
# ['chemist', 'attend', 'department', 'human', 'knowledge', 'alone']
# ['experimentalist', 'advise', 'apply', 'every', 'branch', 'natural']
# []
# ['various', 'machine', 'instruct', 'ought', 'procure']
# ['promise', 'advance', 'enough']
# ['science', 'derange', 'mechanism']
# ['end', 'memorable', 'decide', 'future', 'destiny']
# []
# []
# []
# ['chapter']
# []
# []
# ['comprehensive', 'sense', 'become', 'nearly', 'occupation']
# ['modern', 'inquirer', 'write', 'subject', 'attend']
# ['physiognomy', 'manners', 'account', 'valuable']
# ['waldman', 'found', 'friend', 'gentleness', 'never', 'tinge']
# ['dogmatism', 'instructions', 'given', 'frankness']
# ['light', 'morning', 'whilst', 'engage', 'laboratory']
# []
# ['smile', 'cornelius', 'agrippa', 'whilst', 'waldman']
# ['pass', 'manner', 'visit', 'geneva']
# ['hope', 'experience', 'conceive']
# ['moderate', 'capacity', 'closely', 'pursue', 'study']
# ['depend', 'lesson', 'professor', 'ingolstadt']
# ['return', 'friend', 'native', 'incident']
# ['happen', 'protract']
# ['phenomenon', 'peculiarly', 'attract', 'attention']
# ['whence', 'often', 'ask', 'principle', 'proceed']
# ['question', 'consider']
# ['mystery', 'things', 'brink', 'become']
# ['acquaint', 'cowardice', 'carelessness', 'restrain']
# ['inquiry', 'revolve', 'circumstances', 'determine']
# ['natural', 'philosophy', 'relate', 'physiology', 'unless']
# ['animate', 'almost', 'supernatural', 'enthusiasm', 'application']
# ['observe', 'natural', 'decay', 'corruption', 'human']
# ['impress', 'supernatural', 'horror']
# ['examine', 'cause', 'progress']
# ['charnel', 'house', 'attention', 'fix', 'every', 'object']
# ['degrade', 'waste', 'behold', 'corruption']
# ['death', 'succeed', 'blooming', 'cheek']
# ['inherit', 'wonder', 'brain', 'pause', 'examine']
# ['darkness', 'sudden', 'light', 'break', 'light', 'brilliant']
# ['prospect', 'illustrate', 'surprise', 'among']
# ['science', 'alone', 'reserve', 'discover', 'astonish']
# []
# ['certainly', 'shine', 'heavens', 'affirm']
# ['miracle', 'produce', 'stage']
# ['discovery', 'distinct', 'probable', 'night']
# ['generation', 'become', 'capable', 'bestow']
# ['gratify', 'consummation', 'toil', 'discovery']
# ['open', 'information', 'obtain']
# ['nature', 'rather', 'direct', 'endeavour', 'point']
# ['accomplish', 'arabian', 'bury']
# ['found', 'passage', 'aid', 'glimmering', 'seemingly']
# []
# ['eagerness', 'wonder']
# ['express', 'friend', 'expect', 'inform', 'secret']
# ['acquaint', 'listen', 'patiently']
# ['precept', 'least', 'example', 'dangerous', 'acquirement']
# ['knowledge', 'happy', 'belief', 'native']
# ['concern', 'manner', 'employ']
# ['although', 'possess', 'capacity', 'bestow', 'animation']
# ['prepare', 'frame', 'reception', 'intricacy']
# ['fibre', 'muscle', 'vein', 'still', 'remain', 'inconceivable']
# ['difficulty', 'labour', 'doubt', 'first', 'whether', 'attempt']
# ['creation', 'simple', 'organization']
# ['adequate', 'arduous', 'undertaking', 'doubt']
# ['ultimately', 'succeed', 'prepare', 'multitude', 'reverse']
# ['operations', 'incessantly', 'baffled']
# ['imperfect', 'consider', 'improvement', 'every', 'take']
# ['place', 'science', 'mechanics', 'encourage', 'present']
# ['argument', 'impracticability', 'feelings']
# ['form', 'great', 'hindrance', 'speed', 'resolve', 'contrary', 'first']
# ['intention', 'gigantic', 'stature']
# ['form', 'determination', 'spend', 'month', 'successfully']
# ['hurricane', 'first', 'enthusiasm', 'success', 'death']
# ['appear', 'ideal', 'bounds', 'first', 'break']
# ['torrent', 'light', 'world', 'species', 'bless']
# ['child', 'completely', 'deserve', 'pursue']
# ['matter', 'process', 'although', 'found', 'impossible']
# ['renew', 'death', 'apparently', 'devote', 'corruption']
# ['thought', 'support', 'spirits', 'pursued', 'undertaking']
# ['person', 'become', 'emaciate', 'confinement', 'sometimes']
# ['brink', 'certainty', 'fail', 'still', 'cling']
# ['realise', 'secret', 'alone']
# ['limb', 'tremble', 'remembrance']
# ['resistless', 'almost', 'frantic', 'impulse', 'urge', 'forward', 'seem']
# ['sensation', 'pursuit']
# ['disturb', 'profane', 'finger', 'tremendous', 'secret', 'human']
# ['frame', 'solitary', 'chamber', 'rather', 'house']
# ['separate', 'apartment', 'gallery', 'staircase']
# ['feelings', 'neglect', 'scene', 'around', 'cause']
# ['regularly', 'pardon', 'regard']
# []
# ['thought', 'employment', 'loathsome']
# ['take', 'irresistible', 'imagination', 'wish']
# ['procrastinate', 'relate', 'feelings', 'affection']
# []
# ['thought', 'father', 'unjust', 'ascribe', 'neglect']
# ['faultiness', 'convince']
# ['exception', 'study', 'apply']
# ['tendency', 'weaken', 'affection', 'destroy', 'taste']
# ['study', 'certainly', 'unlawful', 'befit', 'human']
# ['affection', 'greece', 'enslave', 'cæsar', 'spare']
# ['forget', 'moralizing', 'interest']
# []
# ['silence', 'inquiring', 'occupation', 'particularly']
# ['winter', 'spring', 'summer', 'pass', 'labour']
# ['watch', 'blossom', 'expand', 'leaf', 'sights', 'always']
# ['yield', 'supreme', 'delight', 'deeply', 'engross']
# ['close', 'every', 'show', 'plainly']
# ['succeed', 'enthusiasm', 'check', 'anxiety', 'appear']
# ['rather', 'doomed', 'slavery', 'mine']
# ['painful', 'degree', 'startle', 'shun', 'fellow']
# ['creature', 'guilty', 'crime', 'sometimes', 'alarm']
# []
# []
# []
# []
# ['toil', 'anxiety', 'almost', 'amount', 'agony']
# ['already', 'morning', 'patter', 'dismally']
# ['pane', 'candle', 'nearly', 'burn', 'glimmer']
# ['describe', 'emotion', 'catastrophe', 'delineate']
# ['wretch', 'infinite', 'pains', 'endeavour']
# ['limb', 'proportion', 'select', 'feature']
# ['black', 'flowing', 'teeth', 'pearly', 'whiteness']
# ['luxuriance', 'form', 'horrid', 'contrast', 'watery']
# []
# ['purpose', 'infuse', 'inanimate']
# ['exceed', 'moderation', 'finish', 'beauty']
# ['heart', 'unable', 'endure', 'aspect', 'create']
# ['rush', 'continue', 'traverse']
# ['chamber', 'unable', 'compose', 'sleep', 'length', 'lassitude']
# ['clothes', 'endeavour', 'moment', 'forgetfulness']
# ['dream', 'thought', 'elizabeth', 'bloom', 'health', 'walking']
# ['street', 'ingolstadt', 'delight', 'surprise', 'embrace']
# ['imprint', 'first', 'become', 'livid']
# ['death', 'feature', 'appear', 'change', 'thought']
# ['corpse', 'mother', 'shroud', 'envelop']
# ['shutter', 'behold', 'wretch', 'miserable', 'monster']
# ['call', 'fix', 'open', 'mutter']
# ['detain', 'escape', 'rush', 'downstairs', 'refuge']
# ['night', 'walking', 'greatest']
# ['agitation', 'listening', 'attentively', 'catching', 'fear', 'sound']
# ['miserably', 'given']
# []
# ['endue', 'animation', 'hideous', 'wretch']
# []
# ['pass', 'night', 'wretchedly', 'sometimes', 'pulse', 'quickly']
# ['hardly', 'palpitation', 'every', 'artery', 'others', 'nearly']
# ['horror', 'bitterness', 'disappointment', 'dream']
# ['pleasant', 'space', 'become']
# ['change', 'rapid', 'overthrow', 'complete']
# ['morning', 'dismal', 'length', 'dawn', 'discover']
# ['sleepless', 'aching', 'church', 'ingolstadt', 'white', 'steeple']
# ['street', 'pacing', 'quick', 'steps', 'seek', 'avoid']
# ['wretch', 'fear', 'every', 'turning', 'street', 'present']
# ['return', 'apartment', 'inhabit']
# ['black', 'comfortless']
# ['bodily', 'exercise', 'weigh']
# ['traverse', 'street', 'without', 'clear', 'conception']
# ['heart', 'palpitate', 'sickness']
# ['hurry', 'irregular', 'steps', 'daring']
# ['turn']
# ['know', 'frightful', 'fiend']
# []
# ['continue', 'length', 'opposite', 'various']
# ['towards', 'street', 'near', 'observe']
# ['open', 'perceive', 'henry', 'clerval', 'seeing']
# ['instantly', 'spring', 'frankenstein', 'exclaim']
# ['fortunate']
# ['moment', 'alight']
# ['misfortune', 'suddenly', 'first', 'month']
# ['great', 'difficulty', 'persuade', 'father']
# ['indeed', 'believe', 'incredulous', 'constant']
# ['schoolmaster', 'vicar', 'wakefield', 'thousand', 'florin']
# ['without', 'greek', 'heartily', 'without', 'greek']
# ['knowledge']
# ['father', 'brother', 'elizabeth']
# ['short', 'gaze', 'remark']
# ['several', 'night']
# []
# ['length']
# []
# ['tremble', 'excessively', 'endure', 'think']
# ['thought', 'shiver', 'creature']
# ['apartment', 'still', 'alive', 'walking', 'dread']
# ['behold', 'monster', 'fear', 'still', 'henry']
# ['stairs', 'dart', 'towards', 'already']
# ['recollect', 'pause']
# ['shivering', 'throw', 'forcibly']
# ['child', 'accustom', 'expect', 'spectre', 'stand']
# ['waiting', 'nothing', 'appear', 'step']
# ['fearfully', 'apartment', 'empty', 'bedroom', 'free']
# ['hideous', 'guest', 'hardly', 'believe', 'great']
# ['ascend', 'servant', 'presently', 'bring', 'breakfast']
# ['place', 'jump', 'chair', 'clap', 'hands', 'laugh', 'aloud']
# ['clerval', 'first', 'attribute', 'unusual', 'spirits', 'arrival']
# ['laughter', 'frighten', 'astonish']
# ['matter', 'laugh', 'manner']
# ['imagine', 'monster', 'seize']
# ['struggle', 'furiously']
# []
# ['anticipate', 'strangely', 'turn', 'bitterness']
# ['several', 'month', 'henry', 'nurse']
# ['journey', 'wretched', 'sickness']
# ['nurse', 'recovery']
# []
# ['monster', 'bestow', 'existence']
# ['continually', 'recur', 'subject', 'persuade', 'disorder']
# []
# ['capable', 'observe', 'outward', 'object', 'pleasure']
# ['shooting', 'forth', 'tree', 'shade', 'window']
# ['divine', 'spring', 'season', 'contribute', 'greatly']
# ['convalescence', 'sentiment', 'affection', 'revive']
# ['cheerful', 'attack', 'fatal', 'passion']
# []
# ['dearest', 'clerval', 'exclaim']
# ['occasion', 'forgive']
# []
# ['since', 'appear', 'spirits']
# ['speak', 'subject']
# []
# ['tremble', 'subject', 'allude', 'object']
# ['dare', 'think']
# ['compose', 'clerval', 'observe', 'change']
# ['colour', 'mention', 'agitate', 'father']
# ['cousin', 'happy', 'receive', 'letter']
# ['handwriting', 'hardly', 'uneasy']
# []
# ['deserve']
# []
# ['letter', 'lying']
# []
# []
# []
# ['elizabeth']
# []
# []
# ['constant', 'letters']
# ['necessary', 'apprehension', 'thought']
# ['bring', 'persuasion']
# ['prevent', 'encounter', 'inconvenience', 'perhaps', 'danger']
# ['sickbed', 'devolve', 'mercenary', 'nurse', 'never']
# ['getting', 'better', 'eagerly', 'confirm']
# ['intelligence', 'handwriting']
# []
# ['return', 'happy', 'cheerful']
# ['friend', 'dearly', 'father', 'health', 'vigorous']
# ['assure']
# ['activity', 'spirit', 'desirous', 'swiss', 'enter']
# ['foreign', 'service', 'least']
# ['military', 'career', 'distant', 'country', 'ernest', 'never']
# ['become', 'idler', 'unless', 'yield', 'point']
# ['permit', 'enter', 'profession', 'select']
# ['happy', 'face', 'around', 'since']
# ['change', 'take', 'place', 'little', 'household', 'remember']
# ['occasion', 'justine', 'moritz', 'enter', 'family', 'probably']
# ['mother', 'widow', 'child', 'justine']
# ['death', 'moritz', 'treat', 'observe']
# ['justine', 'twelve', 'years', 'prevail', 'mother']
# ['allow', 'house', 'republican', 'institution']
# ['country', 'produce', 'simple', 'happy', 'manners']
# ['prevail', 'great', 'monarchy', 'surround', 'hence']
# ['refine', 'moral', 'servant', 'geneva']
# ['fortunate', 'country', 'include', 'ignorance']
# ['sacrifice', 'dignity', 'human']
# ['justine', 'remember', 'great', 'favourite']
# ['recollect', 'remark', 'humour']
# ['glance', 'justine', 'dissipate', 'reason']
# ['ariosto', 'give', 'concern', 'beauty', 'angelica', 'look']
# ['justine', 'grateful', 'little', 'creature', 'world']
# ['phraseology', 'manners', 'often', 'remind']
# []
# ['trial', 'reserve']
# ['brother', 'sister', 'mother']
# ['exception', 'neglect', 'daughter', 'childless']
# ['confirm', 'conceive', 'accordingly', 'month']
# ['winning', 'mildness', 'manners', 'remarkable']
# ['vivacity', 'residence', 'mother', 'house', 'nature']
# ['oftener', 'accused', 'cause', 'death']
# ['brother', 'sister', 'perpetual', 'fret', 'length', 'throw', 'madame', 'moritz']
# ['decline', 'first', 'increase', 'irritability']
# ['peace', 'first', 'approach', 'weather']
# ['assure', 'tenderly', 'clever', 'gentle']
# ['extremely', 'pretty', 'mention']
# ['expression', 'continually', 'remind']
# []
# ['sweet', 'laugh', 'eyelash', 'curling']
# ['smile', 'little', 'dimple', 'appear', 'cheek']
# ['victor', 'indulge', 'little']
# ['since', 'departure', 'clerval', 'geneva', 'already']
# ['recover', 'spirits', 'report', 'point', 'marry']
# ['older', 'manoir', 'admire', 'favourite']
# ['everybody']
# ['return', 'conclude', 'write', 'dearest', 'victor,—one']
# ['grateful', 'adieu', 'cousin', 'entreat']
# ['write']
# []
# ['elizabeth', 'lavenza']
# []
# []
# ['geneva', 'march']
# []
# ['letter', 'write', 'instantly', 'relieve', 'anxiety']
# ['write', 'exertion', 'greatly', 'fatigue']
# ['sustain', 'since', 'fatal', 'night', 'labour']
# ['health', 'sight', 'chemical', 'instrument', 'renew', 'agony']
# ['nervous', 'symptom', 'henry', 'remove']
# ['perceive', 'acquire', 'dislike']
# ['previously', 'laboratory', 'care', 'clerval']
# ['avail', 'visit', 'professor', 'waldman', 'inflict', 'torture']
# ['mean', 'please', 'torment']
# ['afterwards', 'putting', 'cruel', 'death']
# ['writhe', 'words', 'dare', 'exhibit']
# ['total', 'ignorance', 'conversation', 'general']
# ['surprise', 'never', 'attempt', 'secret']
# ['krempe', 'equally', 'docile', 'condition']
# ['fellow', 'cry', 'clerval', 'assure']
# ['gospel', 'university']
# ['young', 'diffident', 'clerval']
# ['young', 'wear', 'short']
# []
# ['clerval', 'never', 'sympathise', 'taste', 'natural', 'science']
# ['university', 'design', 'making', 'complete']
# ['mark', 'resolve', 'pursue']
# ['inglorious', 'career', 'turn', 'toward', 'afford']
# ['scope', 'spirit', 'enterprise', 'persian', 'arabic', 'sanskrit']
# ['language', 'engage', 'attention', 'easily', 'induce', 'enter']
# ['study', 'idleness', 'irksome']
# ['wish', 'reflection', 'hate', 'former', 'study']
# ['attempt', 'critical', 'knowledge', 'dialect']
# ['contemplate', 'making', 'temporary']
# ['amusement', 'merely', 'understand', 'meaning']
# ['elevate', 'degree', 'never', 'experience', 'studying', 'author']
# ['country', 'writings', 'appear']
# ['consist', 'garden', 'roses,—in', 'smile', 'frown']
# ['different', 'manly', 'heroical', 'poetry', 'greece']
# ['journey', 'retarded', 'ensue', 'spring']
# ['cheerfully', 'although', 'spring', 'uncommonly']
# []
# ['departure', 'henry', 'propose']
# ['personal', 'farewell', 'country', 'inhabit', 'accede']
# ['pleasure', 'proposition', 'exercise', 'clerval']
# ['always', 'favourite', 'companion', 'ramble', 'nature']
# ['take', 'among', 'scene', 'native', 'country']
# ['pass', 'fortnight', 'perambulation', 'health', 'spirits']
# ['excellent', 'friend', 'sincerely', 'endeavour']
# ['elevate', 'level', 'selfish']
# ['pursuit', 'cramp', 'narrow', 'gentleness']
# ['years', 'love', 'beloved', 'sorrow']
# ['happy', 'inanimate', 'nature', 'power', 'bestow']
# ['ecstasy', 'present', 'season', 'indeed', 'divine', 'flower', 'spring']
# ['notwithstanding', 'endeavour', 'throw']
# ['henry', 'rejoice', 'gaiety', 'sincerely', 'sympathise', 'feelings']
# ['resource', 'occasion', 'truly']
# ['astonish', 'conversation', 'imagination', 'often']
# ['fancy', 'passion', 'times', 'repeat', 'favourite', 'poem']
# ['argument', 'support', 'great', 'ingenuity']
# []
# ['dancing', 'every', 'appear', 'happy', 'spirits']
# ['bound', 'along', 'feelings', 'unbridle', 'hilarity']
# []
# []
# []
# ['return', 'found', 'following', 'letter', 'father']
# []
# ['probably', 'wait', 'impatiently', 'letter']
# ['grief', 'shall', 'inflict', 'absent']
# ['prepare', 'woeful']
# ['william', 'dead!—that', 'sweet', 'child', 'whose', 'smile', 'delight', 'warm']
# []
# ['attempt', 'console', 'simply', 'relate']
# ['circumstances', 'transaction']
# ['farther', 'usual', 'already', 'thought']
# ['return', 'presently', 'ernest', 'enquire']
# ['afterwards', 'wait', 'return']
# ['account', 'rather', 'alarm', 'continue', 'search']
# ['night', 'elizabeth', 'conjecture']
# ['return', 'house', 'return']
# ['elizabeth', 'suffer', 'extreme', 'anguish', 'morning']
# ['discover', 'lovely', 'night', 'blooming']
# ['active', 'health', 'stretch', 'grass', 'livid', 'motionless']
# []
# ['countenance', 'betray', 'secret', 'elizabeth', 'earnest']
# ['victim', 'clasp', 'hands', 'exclaim', 'murder']
# []
# ['faint', 'restore', 'extreme', 'difficulty']
# ['evening', 'william', 'tease', 'valuable']
# ['miniature', 'possess', 'mother', 'picture']
# ['trace', 'present', 'although', 'exertion', 'discover']
# ['unremitted', 'restore', 'beloved', 'william']
# []
# ['words', 'pierce', 'heart', 'unhappy']
# ['additional', 'motive', 'return', 'comforter']
# []
# ['feelings', 'peace', 'gentleness', 'instead']
# ['festering', 'wound', 'mind', 'enter', 'house', 'mourning']
# ['affectionate', 'afflict', 'father']
# []
# ['alphonse', 'frankenstein']
# []
# ['geneva']
# []
# []
# ['surprise', 'observe', 'despair', 'succeed', 'first']
# ['express', 'receive', 'friend', 'throw', 'letter']
# ['table', 'cover', 'hands']
# []
# ['bitterness', 'always', 'unhappy', 'friend']
# []
# []
# ['offer', 'consolation', 'friend']
# []
# []
# ['clerval', 'endeavour', 'words', 'consolation']
# ['express', 'heartfelt', 'sympathy', 'william']
# ['lovely', 'child', 'sleep', 'angel', 'mother']
# ['bright', 'joyous', 'young', 'beauty']
# ['untimely', 'miserably', 'murderer', 'grasp']
# ['cover', 'gentle', 'know', 'longer']
# ['subject', 'reserve', 'miserable']
# ['survivor']
# []
# ['clerval', 'spoke', 'hurry', 'street', 'words']
# ['solitude', 'horse', 'arrive', 'hurry']
# ['cabriolet', 'farewell', 'friend']
# ['alter', 'every', 'thing', 'sudden']
# ['degree', 'work', 'alteration', 'although']
# ['tranquilly', 'decisive', 'overcome']
# ['dare', 'advance', 'dread', 'thousand', 'nameless', 'evil', 'tremble']
# ['although', 'unable', 'define']
# ['contemplate', 'waters', 'placid', 'around']
# ['degree', 'heavenly', 'scene', 'restore', 'continue', 'journey']
# ['side', 'bright', 'summit', 'blanc']
# ['child', 'mountain', 'beautiful', 'welcome']
# ['wanderer', 'summit', 'clear']
# ['friend', 'shall', 'render', 'tedious', 'dwelling']
# ['preliminary', 'circumstances', 'comparative']
# ['happiness', 'think', 'pleasure', 'country', 'beloved']
# ['country', 'native', 'delight']
# []
# []
# ['near', 'grief', 'overcome', 'night']
# ['foresee', 'obscurely', 'destine', 'become', 'wretched', 'human']
# ['circumstance', 'misery', 'imagine', 'dread']
# ['conceive', 'hundredth', 'anguish', 'destine', 'endure']
# ['completely', 'arrive', 'environs', 'geneva', 'gates']
# ['secheron', 'village', 'distance', 'league']
# ['william', 'murder']
# ['blanc', 'beautiful', 'figure', 'storm', 'appear', 'approach']
# ['rapidly', 'landing', 'ascend', 'observe']
# ['coming', 'slowly', 'large', 'drop', 'violence', 'quickly', 'increase']
# []
# ['increase', 'every', 'minute', 'thunder', 'burst', 'terrific', 'crash']
# ['echo', 'salêve', 'juras']
# ['every', 'thing', 'seem', 'pitchy', 'darkness', 'recover']
# ['precede', 'flash', 'storm', 'often']
# ['violent', 'storm', 'exactly', 'north']
# []
# ['hasty', 'noble', 'elevated', 'spirits', 'clasp']
# ['hands', 'exclaim', 'aloud', 'william', 'angel']
# ['funeral', 'dirge', 'words', 'perceive']
# ['gloom', 'figure', 'stole', 'behind', 'clump', 'tree', 'stand']
# ['fix', 'gaze', 'intently', 'mistake', 'flash', 'lightning']
# ['gigantic', 'stature', 'deformity', 'aspect', 'hideous', 'belong']
# ['dæmon', 'given']
# ['shudder', 'conception', 'murderer', 'brother', 'sooner']
# ['chatter', 'force', 'support', 'figure']
# ['doubt', 'presence', 'irresistible', 'proof']
# []
# ['continue', 'scene', 'envelop', 'impenetrable', 'darkness']
# ['revolve', 'event', 'seek', 'forget']
# ['whole', 'train', 'progress', 'toward', 'creation', 'appearance']
# ['works', 'hands', 'bedside', 'departure', 'years']
# ['nearly', 'elapse', 'since', 'night', 'first', 'receive']
# ['first', 'crime', 'turn', 'loose', 'world']
# ['deprave', 'wretch', 'whose', 'delight', 'carnage', 'misery']
# ['night', 'spend']
# ['inconvenience', 'weather', 'imagination']
# ['scene', 'despair', 'consider']
# ['among', 'mankind', 'endow', 'power', 'effect', 'purpose']
# ['horror', 'nearly', 'light']
# ['dawn', 'direct', 'steps', 'towards', 'gates']
# ['pause', 'reflect', 'story']
# ['form', 'endue']
# ['remember', 'nervous', 'fever', 'seize']
# ['communicate', 'relation']
# ['persuade', 'relative', 'commence']
# ['resolve', 'remain', 'silent']
# []
# ['morning', 'enter', 'father', 'house']
# ['servant', 'disturb', 'family', 'library']
# []
# ['stand', 'place', 'embrace', 'father']
# ['gaze', 'picture', 'mother', 'stand']
# ['desire', 'represent', 'caroline', 'beaufort', 'agony', 'despair', 'kneeling']
# ['coffin', 'father', 'rustic', 'cheek']
# ['sentiment', 'picture', 'miniature', 'william']
# ['tears', 'flow', 'look', 'engage', 'ernest']
# ['enter', 'hear', 'arrive', 'hasten', 'welcome']
# ['welcome', 'dearest', 'victor']
# ['alleviate', 'presence', 'revive', 'father', 'seem']
# ['sinking', 'misfortune', 'persuasion', 'induce']
# []
# ['tears', 'unrestrained', 'brother', 'sense', 'mortal']
# ['agony', 'creep', 'frame', 'imagine']
# []
# ['ernest', 'require', 'consolation', 'accused']
# ['cause', 'death', 'brother']
# []
# ['night']
# ['reply', 'brother', 'accent']
# ['wonder', 'discovery', 'complete', 'misery']
# []
# ['wrongfully', 'every', 'know', 'belief', 'surely', 'ernest']
# ['confuse', 'evidence', 'fact', 'weight']
# []
# []
# ['relate', 'morning', 'murder', 'william']
# ['discover', 'justine', 'take', 'confine']
# ['happening', 'examine', 'apparel', 'night']
# ['instantly', 'show', 'others', 'without', 'saying']
# []
# []
# ['instant', 'father', 'enter', 'unhappiness', 'deeply', 'impress']
# ['countenance', 'endeavour', 'welcome', 'cheerfully']
# ['exchange', 'mournful', 'greeting', 'introduce']
# ['topic', 'disaster', 'ernest', 'exclaim']
# []
# ['rather', 'ignorant', 'discover']
# []
# []
# ['forbid', 'suffer', 'guilty']
# ['try', 'today', 'sincerely', 'acquit']
# []
# ['speech', 'calm', 'firmly', 'convince']
# ['therefore', 'circumstantial', 'evidence']
# ['bring', 'forward', 'strong', 'enough', 'convict']
# ['announce', 'publicly', 'astound', 'horror', 'look']
# ['madness', 'vulgar', 'indeed', 'exist', 'except']
# ['existence', 'living', 'monument', 'presumption', 'ignorance']
# ['childish', 'years', 'candour', 'vivacity']
# ['welcome', 'greatest', 'affection', 'arrival']
# ['cousin', 'fill', 'perhaps']
# ['lovely', 'darling', 'sincerely']
# ['never', 'shall']
# ['william']
# ['innocent', 'elizabeth', 'shall']
# ['every', 'prejudice', 'deadly', 'manner', 'render']
# []
# ['dearest', 'niece', 'father', 'tears']
# ['believe', 'innocent', 'justice']
# ['activity', 'shall', 'prevent', 'slight', 'shadow']
# []
# ['pass', 'hours', 'eleven', 'o’clock', 'trial']
# ['commence', 'father', 'family', 'oblige', 'attend']
# ['witness', 'accompany', 'court', 'whole']
# ['decide', 'whether', 'result', 'curiosity', 'lawless', 'devices']
# ['innocence', 'dreadfully', 'murder', 'every']
# ['aggravation', 'infamy', 'murder', 'memorable', 'horror']
# ['ignominious', 'grave', 'cause', 'thousand', 'times', 'rather']
# ['confess', 'guilty', 'crime', 'ascribe', 'justine']
# ['absent', 'commit', 'declaration']
# ['consider', 'raving', 'madman']
# ['feelings', 'exquisitely', 'beautiful', 'appear', 'confident']
# ['innocence', 'tremble', 'although', 'gaze', 'execrate']
# ['excite', 'obliterate', 'mind', 'spectator']
# ['imagination', 'enormity', 'suppose', 'commit']
# ['confusion', 'adduce', 'proof', 'guilt']
# ['work', 'appearance', 'courage', 'enter']
# ['recover', 'sorrowful', 'affection', 'seem', 'attest']
# ['utter', 'guiltlessness']
# []
# ['trial', 'begin', 'advocate', 'state']
# ['charge', 'several', 'witness', 'call', 'several', 'strange', 'fact', 'combine']
# ['innocence', 'whole', 'night']
# ['perceive', 'market', 'woman']
# ['o’clock', 'inquire', 'pass', 'night']
# ['anything', 'hear', 'concern', 'show']
# ['violent', 'hysterics', 'several']
# ...
# ['mental', 'torment', 'bodily', 'exercise', 'overflow', 'misery']
# ['excess', 'agitation', 'endure', 'render', 'incapable']
# ['exertion', 'throw', 'leaning', 'hands']
# ['company', 'shadow', 'recollection']
# ['tears', 'stream', 'cease', 'moment']
# ['nothing', 'appear', 'fiend']
# ['snatch', 'every', 'future', 'happiness', 'creature']
# ['miserable', 'frightful', 'event', 'single', 'history']
# []
# ['dwell', 'incident', 'follow']
# ['relate', 'tedious']
# ['friend', 'snatch', 'desolate']
# ['hideous', 'narration']
# ['tidings', 'excellent', 'venerable']
# ['delight', 'elizabeth', 'daughter', 'dote']
# ['affection', 'feel', 'decline']
# ['fiend', 'bring', 'misery', 'hair', 'doomed', 'waste']
# ['wretchedness', 'horror', 'accumulate']
# ['around', 'spring', 'existence', 'suddenly', 'unable']
# []
# ['become', 'sensation', 'chains']
# ['darkness', 'object', 'press', 'sometimes']
# ['indeed', 'dream', 'wander', 'flowery', 'meadow', 'pleasant', 'vale']
# ['conception', 'misery', 'situation', 'release']
# ['prison', 'call', 'month']
# ['awaken', 'reason', 'awaken', 'revenge']
# ['abroad', 'world', 'destruction', 'possess']
# ['revenge', 'curse']
# ['confine', 'useless', 'wish', 'begin']
# ['reflect', 'means', 'secure', 'purpose']
# ['accusation']
# ['however', 'wonderful', 'force', 'conviction', 'story', 'connect']
# ['mistake', 'dream', 'motive', 'falsehood']
# ['heart', 'resolution', 'pursue', 'destroyer', 'death', 'purpose']
# ['quiet', 'agony', 'interval', 'reconcile', 'relate']
# ['history', 'briefly', 'firmness', 'precision', 'marking', 'date']
# ['become', 'attentive', 'interest', 'sometimes', 'shudder']
# ['horror', 'others', 'lively', 'surprise', 'unmingled', 'disbelief', 'paint']
# ['countenance']
# ['conclude', 'narration']
# ['accuse', 'whose', 'seizure', 'punishment', 'exert']
# ['feelings', 'revolt', 'execution']
# []
# ['officially', 'consequence', 'whole', 'incredulity']
# ['power', 'exertion', 'defiance', 'follow']
# ['commission', 'crime', 'conjecture', 'place']
# ['doubt', 'hover', 'inhabit']
# ['credit', 'narrative', 'intend', 'pursue', 'enemy']
# ['punishment', 'desert']
# []
# ['spoke', 'sparkle', 'magistrate', 'intimidate']
# ['mistake', 'exert']
# ['describe', 'property', 'prove']
# ['little', 'avail']
# ['loose', 'society', 'still', 'exist', 'refuse', 'demand']
# ['resource', 'devote', 'either', 'death']
# ['tremble', 'excess', 'agitation', 'frenzy']
# ['manner', 'something', 'doubt', 'haughty', 'fierceness']
# ['madness', 'endeavour', 'soothe', 'nurse', 'child']
# ['cry', 'ignorant', 'pride']
# ['wisdom', 'cease']
# []
# ['break', 'house', 'angry', 'disturb', 'retire', 'meditate']
# ['action']
# []
# ['chapter']
# []
# []
# ['allow', 'calculate', 'period', 'otherwise']
# ['delirium', 'death', 'portion']
# []
# ['first', 'resolution', 'geneva', 'country']
# ['happy', 'beloved', 'adversity', 'become']
# ['hateful', 'provide', 'money', 'together', 'jewel']
# ['belong', 'mother', 'departed']
# ['live', 'hardly', 'times', 'stretch', 'failing', 'limb']
# ['leave', 'adversary']
# []
# ['entrance', 'cemetery', 'william', 'elizabeth', 'father']
# ['repose', 'enter', 'approach', 'mark']
# ['shadow', 'around']
# []
# ['despair', 'live', 'murderer', 'live']
# ['destroy', 'weary', 'existence', 'kneel', 'grass']
# ['sacred', 'earth', 'kneel', 'shades', 'wander']
# ['eternal', 'grief', 'swear', 'night']
# ['spirits', 'wandering']
# []
# ['answer', 'stillness', 'night', 'fiendish']
# ['destroy', 'miserable', 'existence', 'hear']
# ['determine', 'satisfy']
# ['pursued', 'month', 'guide']
# ['follow', 'track', 'sometimes', 'peasant', 'scare']
# ['horrid', 'apparition', 'inform', 'sometimes']
# ['guide', 'snow', 'descend']
# ['print', 'white', 'plain', 'first', 'entering']
# ['still', 'fatigue']
# ['carry', 'eternal', 'still', 'spirit']
# ['follow', 'direct', 'steps', 'murmur', 'suddenly']
# ['doubt', 'spirits']
# ['invoke', 'often', 'heavens', 'cloudless']
# ['drop', 'revive', 'vanish']
# ['follow', 'course', 'river', 'dæmon']
# ['country', 'chiefly', 'collect', 'place', 'human', 'being', 'seldom']
# ['generally', 'subsist', 'animal', 'cross']
# ['money', 'gain', 'friendship', 'villager']
# ['taking', 'small', 'always', 'present']
# ['provide', 'utensil', 'cooking']
# ['pass', 'indeed', 'hateful']
# ['sleep', 'alone', 'taste', 'bless', 'sleep', 'often']
# ['miserable', 'repose', 'dream', 'lull', 'rapture']
# ['spirits', 'guard', 'provide', 'moment', 'rather', 'hours']
# ['happiness', 'retain', 'strength', 'fulfil', 'pilgrimage', 'deprive']
# ['sustain', 'inspirit', 'night', 'sleep']
# ['voice', 'behold', 'clerval', 'enjoy', 'health', 'youth', 'often', 'weary']
# ['toilsome', 'march', 'persuade', 'dreaming', 'night']
# ['form', 'sometimes', 'haunt', 'waking', 'hours']
# ['destruction', 'dæmon', 'enjoin', 'heaven']
# ['ardent', 'desire']
# ['feelings', 'pursued', 'sometimes', 'indeed']
# []
# ['miserable', 'fiend', 'torture', 'death', 'never', 'search']
# []
# ['inscription', 'words', 'prepare', 'toil']
# ['begin', 'provide', 'shall', 'enter']
# ['journey', 'suffering', 'satisfy', 'everlasting']
# ['resolve', 'purpose', 'calling', 'heaven', 'support']
# ['ocean', 'appear', 'distance', 'form', 'utmost', 'boundary']
# ['horizon', 'unlike', 'season']
# ['south', 'cover', 'distinguish']
# ['behold', 'mediterranean', 'hill', 'hail']
# ['rapture', 'boundary', 'toil', 'kneel']
# ['grapple']
# ['fiend', 'possess', 'advantage', 'found']
# ['hope', 'intercept', 'reach', 'beach']
# ['fiend', 'gain', 'accurate', 'information', 'gigantic', 'monster']
# ['terrific', 'appearance', 'carry', 'store', 'winter']
# ['night', 'horror', 'strike', 'villager', 'pursued']
# ['journey', 'across', 'direction']
# []
# ['escape', 'commence', 'destructive', 'almost', 'endless']
# ['genial', 'sunny', 'climate', 'survive']
# ['round', 'instigate', 'revenge', 'prepare', 'journey']
# ['departed']
# []
# ['guess', 'pass', 'since', 'endure']
# ['burning', 'within', 'heart', 'enable', 'support', 'immense']
# ['rugged', 'mountain', 'often', 'bar', 'passage', 'often', 'hear']
# ['frost', 'path', 'secure']
# ['animal', 'convey', 'incredible', 'gain']
# ['summit', 'slope', 'mountain', 'sinking', 'fatigue']
# ['view', 'expanse', 'anguish', 'suddenly']
# ['discover', 'utter', 'ecstasy']
# ['distinguish', 'sledge', 'distort', 'proportion', 'know']
# ['intercept', 'dæmon', 'still', 'sight']
# []
# ['absolutely', 'necessary', 'bitterly']
# ['irksome', 'continue', 'route', 'sledge', 'still', 'visible']
# ['perceptibly', 'gain', 'nearly', 'journey']
# ['appear', 'almost', 'within', 'grasp', 'hope']
# ['suddenly', 'extinguish', 'trace', 'utterly']
# ['ground', 'hear', 'thunder', 'progress']
# ['terrific', 'press', 'arise', 'roar']
# ['tremendous', 'overwhelm', 'sound', 'finish']
# ['drifting', 'scatter', 'piece', 'continually', 'lessening']
# ['prepare', 'hideous', 'death']
# []
# ['manner', 'appalling', 'hours', 'pass', 'several']
# ['accumulation', 'distress']
# ['means', 'enable', 'infinite', 'fatigue']
# ['direction', 'determine', 'going', 'southward']
# ['still', 'trust', 'mercy', 'rather', 'abandon']
# ['purpose', 'hope', 'induce', 'grant', 'pursue']
# ['enemy', 'direction', 'northward', 'board']
# ['vigour', 'exhaust', 'multiply']
# ['hardship', 'death', 'still', 'dread', 'unfulfilled']
# ['satisfy', 'vengeance', 'death']
# ['selfish', 'appear']
# ['minister', 'vengeance', 'conduct', 'swear']
# ['survive', 'crime', 'eloquent']
# ['persuasive', 'words', 'power', 'heart']
# ['trust', 'hellish', 'treachery']
# ['fiend', 'malice', 'names', 'william']
# ['thrust', 'sword', 'heart', 'hover', 'direct']
# ['steel', 'aright']
# ['walton', 'continuation']
# []
# []
# ['strange', 'terrific', 'story', 'margaret']
# ['blood', 'congeal', 'horror', 'curdle']
# ['others', 'voice', 'break', 'pierce', 'utter']
# ['apparition', 'monster', 'bring']
# ['however', 'earnest', 'connect', 'monster', 'really', 'existence']
# ['creature', 'formation', 'point', 'impenetrable']
# ['senseless', 'curiosity', 'create']
# []
# ['frankenstein', 'discover', 'note', 'concern', 'history', 'ask']
# ['correct', 'augment', 'place']
# ['posterity']
# ['every', 'consolation']
# ['death', 'enjoy', 'comfort', 'offspring', 'solitude']
# ['delirium', 'belief', 'dream', 'hold', 'converse']
# ['conversation', 'always', 'confine', 'history']
# ['eloquence', 'forcible', 'touching', 'relate']
# ['without', 'tears', 'glorious', 'creature']
# ['prosperity', 'noble', 'godlike', 'seem']
# ['worth', 'greatness']
# []
# ['younger', 'believe', 'destine']
# ['deem', 'criminal', 'throw', 'useless', 'grief', 'talent']
# ['useful', 'fellow', 'creature', 'reflect']
# ['animal', 'common', 'projector']
# ['thought', 'support', 'commencement', 'career']
# ['serve', 'plunge', 'lower', 'speculation', 'hope']
# ['analysis', 'application', 'intense', 'union', 'quality']
# ['conceive', 'execute', 'creation']
# []
# ['admirable', 'long', 'friend']
# ['seek', 'sympathise', 'behold', 'desert']
# ['found', 'gain']
# ['miserable', 'wretch', 'speak', 'fresh']
# ['affection', 'strongly', 'move', 'superior', 'excellence']
# ['mind', 'hardly', 'later', 'friend', 'obtain']
# ['never', 'eradicate', 'judge', 'action']
# ['certain', 'conclusion', 'integrity', 'motive', 'sister']
# ['brother', 'never', 'unless', 'indeed', 'symptom', 'show', 'early']
# ['suspect', 'fraud', 'false', 'dealing', 'another', 'friend']
# ['contemplate', 'suspicion', 'enjoy', 'friend']
# ['habit', 'association', 'merit', 'wherever']
# ['clerval', 'whisper']
# ['feeling', 'solitude', 'persuade', 'preserve']
# ['engage', 'undertaking', 'design', 'fraught', 'extensive']
# []
# ['beloved', 'sister']
# ['september']
# []
# []
# ['doomed', 'england', 'dear', 'friend', 'inhabit']
# ['situation', 'courage', 'hope', 'desert']
# ['terrible', 'reflect', 'life', 'endanger']
# ['margaret', 'state']
# ['visiting', 'despair', 'torture']
# ['prospect', 'terrible', 'death', 'husband']
# ['unfortunate', 'guest', 'regard', 'tender', 'compassion']
# ['endeavour', 'talks', 'possession']
# ['happen', 'navigator', 'attempt', 'spite']
# ['expectation', 'delay', 'fill', 'almost', 'dread', 'mutiny']
# ['september']
# []
# ['highly', 'probable', 'papers', 'never', 'reach']
# ['forbear', 'recording']
# ['still', 'surround', 'mountain', 'still', 'imminent', 'danger']
# ['desolation', 'frankenstein', 'daily', 'decline', 'health', 'feverish']
# ['lifelessness']
# []
# ['mention', 'letter', 'fear', 'entertain', 'mutiny']
# ['close', 'limb', 'hanging', 'listlessly', 'rouse']
# ['dozen', 'sailor', 'demand', 'admission', 'cabin']
# ['enter', 'leader', 'address']
# ['fear', 'possible', 'dissipate']
# ['force', 'enough', 'attend', 'rouse', 'sparkle']
# []
# []
# ['expedition', 'wherefore', 'glorious']
# ['smooth', 'placid', 'southern', 'danger']
# ['courage', 'exhibit', 'danger', 'death', 'surround']
# ['brave', 'overcome', 'glorious']
# ['honourable', 'undertaking', 'hereafter', 'hail']
# ['hand', 'strength', 'enough', 'endure']
# ['peril', 'soul', 'chilly', 'return']
# ['coward', 'steady']
# ['hearts', 'mutable', 'withstand']
# ['speech', 'lofty', 'design', 'heroism']
# ['unable', 'reply', 'spoke', 'retire', 'consider']
# ['return']
# []
# ['almost', 'deprive']
# ['return', 'shamefully', 'purpose', 'unfulfilled']
# ['unsupported', 'idea', 'glory', 'honour', 'never']
# []
# []
# []
# []
# []
# ['glory', 'friend', 'endeavour', 'detail']
# ['bitter', 'circumstances', 'sister', 'waft']
# ['towards', 'england', 'towards', 'despond']
# ['september', 'begin', 'roaring', 'thunder', 'hear']
# ['imminent', 'peril', 'remain', 'passive', 'chief']
# ['passage', 'towards', 'south', 'become', 'perfectly']
# ['sailor', 'return', 'native']
# ['continue', 'frankenstein', 'doze', 'awake', 'ask']
# []
# ['really', 'return']
# []
# ['unwillingly', 'danger', 'return']
# ['surely', 'spirits', 'assist', 'vengeance', 'endow']
# []
# ['restore', 'often', 'thought']
# ['sentence', 'pronounce', 'grieve', 'patient']
# ['watching', 'close', 'thought', 'sleep']
# ['presently', 'call', 'feeble', 'voice', 'bidding']
# ['walton', 'moment', 'existence', 'burning']
# ['hatred', 'ardent', 'desire', 'revenge', 'express']
# ['justify', 'desire', 'death', 'adversary']
# ['enthusiastic', 'madness', 'create', 'rational', 'creature']
# ['bound', 'towards', 'assure', 'power', 'happiness']
# ['duty', 'towards', 'being', 'species', 'greater', 'claim']
# ['attention', 'include', 'greater', 'proportion', 'happiness']
# ['misery', 'urge', 'refuse', 'right', 'refuse']
# ['ask', 'undertake', 'unfinished', 'renew', 'request']
# ['induce', 'reason', 'virtue']
# ['return', 'england']
# ['point', 'balancing', 'esteem', 'duty']
# ['approach', 'death', 'think', 'right']
# []
# ['respects', 'momentarily', 'expect', 'release']
# ['happy', 'enjoy', 'several', 'years', 'form']
# ['beloved', 'hasten', 'farewell']
# ['apparently', 'innocent', 'distinguish']
# ['science', 'discovery']
# ['blast', 'hope', 'another', 'succeed']
# []
# ['effort', 'silence', 'afterwards']
# ['glorious', 'spirit', 'enable', 'understand']
# ['depth', 'sorrow', 'express', 'inadequate']
# ['interrupt', 'sound', 'portend', 'midnight']
# ['sound', 'human', 'voice', 'hoarse', 'come', 'cabin']
# ['remains', 'frankenstein', 'still', 'arise', 'examine']
# []
# ['enter', 'cabin', 'remains', 'fate', 'admirable']
# ['describe', 'gigantic', 'stature', 'uncouth', 'distort']
# ['proportion', 'coffin', 'conceal']
# ['apparent', 'texture', 'mummy', 'hear', 'sound']
# ['towards', 'window', 'never', 'behold', 'vision', 'horrible']
# ['loathsome', 'appalling', 'hideousness', 'involuntarily']
# ['call']
# []
# ['pause', 'looking', 'wonder', 'turning', 'towards']
# ['uncontrollable', 'passion']
# ['avail', 'pardon', 'irretrievably', 'destroy']
# ['destroy', 'lovedst', 'answer']
# []
# []
# ['obey', 'dying', 'request', 'friend', 'destroy']
# ['enemy', 'suspend', 'mixture', 'curiosity', 'compassion']
# ['approach', 'tremendous', 'dare', 'raise']
# ['attempt', 'speak', 'words', 'monster']
# []
# ['repentance', 'superfluous']
# []
# ['agony', 'remorse', 'continue', 'point', 'corpse']
# ['thousandth', 'portion', 'anguish']
# ['lingering', 'detail', 'execution', 'frightful', 'selfishness', 'hurry']
# ['groan', 'clerval', 'music', 'heart', 'fashion']
# ['hatred', 'endure', 'violence', 'change', 'without']
# ['torture', 'imagine']
# ['existence', 'unspeakable', 'torment', 'dare']
# ['recollect', 'threat', 'resolve', 'accomplish']
# ['prepare', 'deadly', 'torture']
# ['slave', 'master', 'impulse', 'detest']
# ['disobey', 'miserable']
# ['feeling', 'subdue', 'anguish', 'excess']
# ['despair', 'thenceforth', 'become', 'urge']
# []
# ['persuasion', 'lifeless']
# ['friend', 'indignation', 'rekindle', 'within', 'wretch']
# ['whine', 'desolation']
# ['throw', 'torch', 'building']
# ['mourn', 'still', 'live', 'still', 'object']
# ['power']
# []
# ['interrupt']
# ['impression', 'convey', 'appear']
# ['sympathy', 'first', 'seek']
# ['virtue', 'feelings', 'happiness', 'affection', 'whole']
# ['bitter', 'loathing', 'despair', 'sympathy']
# ['fancy', 'soothe', 'dream', 'virtue', 'enjoyment']
# ['excellent', 'quality', 'capable', 'unfolding']
# ['nourish', 'thought', 'honour', 'devotion', 'crime']
# ['malignity', 'misery', 'found', 'comparable']
# ['fall', 'angel', 'become', 'malignant', 'devil', 'enemy']
# ['frankenstein', 'friend', 'knowledge']
# ['crime', 'misfortune', 'detail']
# ['hours', 'month', 'misery', 'endure']
# ['satisfy', 'desire', 'ardent', 'craving', 'still']
# ['humankind', 'sin', 'felix', 'drove']
# ['friend', 'contumely', 'execrate', 'rustic']
# ['wretch', 'murder', 'lovely']
# ['devote', 'creator', 'select', 'specimen', 'worthy']
# ['admiration', 'among', 'misery', 'pursued']
# ['irremediable', 'white', 'death']
# ['abhorrence', 'equal', 'regard']
# ['hands', 'execute', 'think', 'heart']
# ['imagination', 'conceive', 'moment', 'hands']
# ['shall', 'instrument', 'future', 'mischief']
# ['nearly', 'complete', 'neither', 'death', 'need']
# ['consummate', 'series', 'accomplish']
# ['sacrifice', 'shall', 'vessel', 'bring']
# ['collect', 'funeral', 'consume', 'ash', 'miserable', 'frame']
# ['create', 'another', 'shall', 'shall', 'longer']
# ['longer', 'star', 'wind', 'cheek', 'light']
# ['happiness', 'years', 'image', 'world', 'afford', 'first']
# ['open', 'cheering', 'warmth', 'summer', 'hear']
# ['crime', 'bitter', 'remorse']
# ['farewell', 'leave', 'humankind']
# ['satiate', 'destruction']
# ['didst', 'extinction', 'cause', 'greater', 'wretchedness']
# ['unknown', 'hadst', 'cease', 'think']
# ['wound', 'death', 'shall', 'close']
# []
# ['cry', 'solemn', 'enthusiasm']
# ['shall', 'longer', 'burning']
# ['exult', 'agony', 'torturing', 'flame', 'light', 'conflagration']
# ['ash', 'sweep', 'wind', 'spirit']
# ['sleep', 'peace', 'think', 'surely', 'think']
# ['farewell']
# []
# ['darkness', 'distance']

# %% [markdown]
# ## LDA with Gensim

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]

import pickle
pickle.dump(corpus, open('corpus.pkl', 'wb'))
dictionary.save('dictionary.gensim')

# %%
import gensim
NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
ldamodel.save('model5.gensim')
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.013*"become" + 0.009*"night" + 0.008*"death" + 0.007*"sometimes"')
# (1, '0.010*"found" + 0.010*"miserable" + 0.010*"moment" + 0.008*"clerval"')
# (2, '0.008*"friend" + 0.008*"every" + 0.007*"hear" + 0.007*"return"')
# (3, '0.011*"elizabeth" + 0.010*"thought" + 0.010*"appear" + 0.010*"feelings"')
# (4, '0.009*"first" + 0.008*"remain" + 0.008*"often" + 0.008*"enter"')

# %% [markdown]
# ## pyLDAvis

# %%
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = pickle.load(open('corpus.pkl', 'rb'))
lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')
import pyLDAvis.gensim
lda_display = pyLDAvis.gensim.prepare(lda, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el6071150679556804390529460"></div>
# <script type="text/javascript">
#
# var ldavis_el6071150679556804390529460_data = {"mdsDat": {"x": [-0.11224984316325091, -0.1389950333624816, 0.040893703679967815, 0.060601486596088085, 0.14974968624967638], "y": [-0.17509031414664517, 0.12160930928876255, 0.09895222208564333, -0.00013468992379616815, -0.045336527303964445], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [19.100897816876593, 18.77939156798627, 20.13310529301705, 20.150970683782592, 21.835634638337496]}, "tinfo": {"Term": ["become", "moment", "night", "appear", "miserable", "elizabeth", "feelings", "remain", "often", "found", "death", "enter", "thought", "little", "child", "clerval", "horror", "first", "pass", "hours", "world", "peace", "crime", "cause", "sound", "express", "possess", "sometimes", "happiness", "heart", "become", "crime", "cause", "world", "possess", "live", "answer", "memory", "create", "peace", "england", "understand", "chapter", "fill", "perhaps", "blood", "break", "shadow", "demand", "toil", "progress", "names", "grasp", "capable", "examine", "consolation", "judge", "really", "vengeance", "fresh", "years", "reflect", "revenge", "human", "night", "sometimes", "happiness", "death", "therefore", "whole", "dream", "indeed", "creature", "house", "light", "pass", "friend", "moment", "express", "passion", "child", "study", "kindness", "restore", "little", "science", "deprive", "fancy", "expect", "turn", "lovely", "fulfil", "carry", "descend", "victor", "letters", "afford", "cry", "useless", "collect", "exist", "neglect", "youth", "move", "silent", "chance", "master", "miserable", "found", "clerval", "around", "felix", "steps", "visit", "pleasure", "death", "among", "fear", "country", "towards", "scene", "discover", "place", "affection", "follow", "delight", "happiness", "cottage", "inhabit", "purpose", "bestow", "persuade", "reason", "prepare", "feeling", "leave", "heaven", "distance", "force", "ocean", "experience", "happen", "remorse", "safety", "farewell", "subject", "wait", "corpse", "mile", "star", "trembling", "detail", "chair", "raise", "proportion", "intend", "incident", "dress", "engage", "sister", "justine", "companion", "destroy", "relate", "mountain", "suddenly", "wretch", "shore", "every", "hear", "object", "return", "friend", "perceive", "believe", "manner", "among", "still", "form", "continue", "murder", "cottage", "place", "father", "despair", "happy", "sound", "gentle", "young", "imagination", "beauty", "consent", "advance", "forward", "darkness", "image", "circumstances", "enough", "oblige", "direction", "divine", "revive", "overwhelm", "disturb", "spring", "angel", "hunger", "view", "accompany", "confirm", "breeze", "possession", "injury", "sorrowful", "shock", "entirely", "feelings", "elizabeth", "different", "beautiful", "cottager", "appear", "conversation", "thought", "native", "virtue", "greater", "father", "anguish", "seem", "cousin", "creature", "place", "sleep", "letter", "towards", "heart", "country", "return", "friend", "affection", "every", "first", "journey", "horror", "hours", "language", "within", "surprise", "remain", "d\u00e6mon", "imagine", "departed", "determine", "solitude", "abhor", "awake", "frame", "society", "ought", "instrument", "occasion", "perform", "strength", "protector", "courage", "hasten", "explanation", "stature", "gigantic", "near", "recollection", "chemical", "survive", "often", "alone", "sensation", "enter", "sight", "several", "arrive", "reflection", "resolve", "first", "endure", "pass", "appearance", "desire", "enjoy", "heart", "throw", "never", "night", "misery", "month", "present", "labour", "geneva", "still", "appear", "shall", "return"], "Freq": [32.0, 24.0, 42.0, 39.0, 29.0, 37.0, 31.0, 25.0, 27.0, 35.0, 42.0, 30.0, 41.0, 18.0, 18.0, 26.0, 18.0, 41.0, 28.0, 17.0, 15.0, 16.0, 15.0, 15.0, 15.0, 14.0, 14.0, 32.0, 22.0, 34.0, 32.04195260714188, 14.974054268794033, 14.820635232273368, 15.167254037821351, 14.212647862343845, 11.61964392005818, 11.52557444783177, 11.293913807486229, 10.898351990749962, 15.43384855 ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-f5355aa06392> in <module>
# ----> 1 lda3 = gensim.models.ldamodel.LdaModel.load('model3.gensim')
#       2 lda_display3 = pyLDAvis.gensim.prepare(lda3, corpus, dictionary, sort_topics=False)
#       3 pyLDAvis.display(lda_display3)
#
# ~/Desktop/ECS189L/TopicModelingProject/venv/lib/python3.6/site-packages/gensim/models/ldamodel.py in load(cls, fname, *args, **kwargs)
#    1636         """
#    1637         kwargs['mmap'] = kwargs.get('mmap', None)
# -> 1638         result = super(LdaModel, cls).load(fname, *args, **kwargs)
#    1639
#    1640         # check if `random_state` attribute has been set after main pickle load
#
# ~/Desktop/ECS189L/TopicModelingProject/venv/lib/python3.6/site-packages/gensim/utils.py in load(cls, fname, mmap)
#     433         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     434
# --> 435         obj = unpickle(fname)
#     436         obj._load_specials(fname, mmap, compress, subname)
#     437         logger.info("loaded %s", fname)
#
# ~/Desktop/ECS189L/TopicModelingProject/venv/lib/python3.6/site-packages/gensim/utils.py in unpickle(fname)
#    1393
#    1394     """
# -> 1395     with open(fname, 'rb') as f:
#    1396         # Because of loading from S3 load can't be used (missing readline in smart_open)
#    1397         if sys.version_info > (3, 0):
#
# ~/Desktop/ECS189L/TopicModelingProject/venv/lib/python3.6/site-packages/smart_open/smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, transport_params)
#     185         encoding=encoding,
#     186         errors=errors,
# --> 187         newline=newline,
#     188     )
#     189     if fobj is not None:
#
# ~/Desktop/ECS189L/TopicModelingProject/venv/lib/python3.6/site-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, ignore_ext, buffering, encoding, errors, newline)
#     285         open_kwargs['errors'] = errors
#     286
# --> 287     return _builtin_open(local_path, mode, buffering=buffering, **open_kwargs)
#     288
#     289
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model3.gensim'
